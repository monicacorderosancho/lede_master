# %%
import pandas as pd

# %%
import camelot

# %% [markdown]
# # players.pdf
#
# Needs `flavor=stream`

# %%
tables = camelot.read_pdf('players.pdf')
tables
# Out:
# <TableList n=0>

# %%
tables = camelot.read_pdf('players.pdf', flavor='stream')
tables
# Out:
# <TableList n=1>

# %%
tables[0].parsing_report
# Out:
# {'accuracy': 100.0, 'whitespace': 0.0, 'order': 1, 'page': 1}

# %%
tables[0].df
# Out:
#                      0                  1       2      3    4         5
# 0               Player                Pos  Status     Ht   Wt       DOB
# 1          Rhett Bomar        Quarterback  Active   6'2'  215    7/2/85
# 2             Joe Webb        Quarterback  Active   6'4'  220  11/14/86
# 3     Christian Ponder        Quarterback  Active   6'2'  229   2/25/88
# 4      Adrian Peterson       Running Back  Active   6'1'  217   3/21/85
# 5       Lorenzo Booker       Running Back  Active  5'10'  191   6/14/84
# 6       Ryan D'Imperio       Running Back  Active   6'3'  240   8/15/87
# 7           Jeff Dugan       Running Back  Active   6'4'  258    4/8/81
# 8         Toby Gerhart       Running Back  Active   6'1'  237   3/28/87
# 9       Greg Camarillo      Wide Receiver  Active   6'1'  190   4/18/82
# 10    Juaquin Iglesias      Wide Receiver  Active   6'0'  204   8/22/87
# 11       Freddie Brown      Wide Receiver  Active   6'4'  215   6/24/86
# ...

# %% [markdown]
# # 2012.EXP.FINAL.pdf

# %%
tables = camelot.read_pdf('2012.EXP.FINAL.pdf')
tables
# Out:
# <TableList n=2>

# %%
# %matplotlib inline

# %%
camelot.plot(tables[0], kind='contour')

# %%
tables = camelot.read_pdf('2012.EXP.FINAL.pdf', pages='10,11,12')
tables
# Out:
# <TableList n=3>

# %%
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-24-14acecfc65ab> in <module>
# ----> 1 tables[3].df
#
# ~/.pyenv/versions/3.6.7/lib/python3.6/site-packages/camelot/core.py in __getitem__(self, idx)
#     638
#     639     def __getitem__(self, idx):
# --> 640         return self._tables[idx]
#     641
#     642     @staticmethod
#
# IndexError: list index out of range
