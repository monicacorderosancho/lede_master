# %%
import requests
## go and get this webpage

# %%
## https://data.cityofnewyork.us/resource/b9km-gdpy.geojson | geojason OR jason
url = 'https://data.cityofnewyork.us/resource/b9km-gdpy.json'
response = requests.get(url)
data = response.json()

# %%
### Here's the documentation https://dev.socrata.com/foundry/data.cityofnewyork.us/b9km-gdpyprin(
data
# Out:
# [{'unique_key': 'NYCC44522628',
#   'account': 'NYCC44',
#   'opendate': '2021-04-11T00:00:00.000',
#   'complaint_type': 'Sanitation',
#   'zip': '11218',
#   'borough': 'Brooklyn',
#   'city': 'Brooklyn',
#   'council_dist': 'NYCC39',
#   'community_board': '12 Brooklyn'},
#  {'unique_key': 'NYCC01512662',
#   'account': 'NYCC01',
#   'opendate': '2021-04-11T00:00:00.000',
#   'complaint_type': 'Governmental Operations',
#   'zip': '10002',
#   'borough': 'Manhattan',
#   'city': 'New York',
#   'council_dist': 'NYCC01',
#   'community_board': '03 Manhattan'},
#  {'unique_key': 'NYCC02526000',
#   'account': 'NYCC02',
#   'opendate': '2021-04-10T00:00:00.000',
#   'complaint_type': 'Transportation',
#   'descriptor': 'Parking Restrictions',
#   'zip': '10003',
#   'borough': 'Manhattan',
#   'city': 'New York',
#   'council_dist': 'NYCC02',
#   'community_board': '03 Manhattan'},
#  {'unique_key': 'NYCC02526002',
#   'account': 'NYCC02',
#   'opendate': '2021-04-10T00:00:00.000',
# ...

# %%
type(data)
# Out:
# list

# %%
import pandas as pd
# Out:
# /Users/monicacordero/.pyenv/versions/3.8.10/lib/python3.8/site-packages/pandas-1.4.0.dev0+143.g5675cd8ab2-py3.8-macosx-11.3-arm64.egg/pandas/compat/__init__.py:124: UserWarning: Could not import the lzma module. Your installed Python is incomplete. Attempting to use lzma compression will result in a RuntimeError.
#   warnings.warn(msg)

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#        unique_key account                 opendate           complaint_type  \
# 0    NYCC44522628  NYCC44  2021-04-11T00:00:00.000               Sanitation
# 1    NYCC01512662  NYCC01  2021-04-11T00:00:00.000  Governmental Operations
# 2    NYCC02526000  NYCC02  2021-04-10T00:00:00.000           Transportation
# 3    NYCC02526002  NYCC02  2021-04-10T00:00:00.000                 COVID-19
# 4    NYCC02525999  NYCC02  2021-04-10T00:00:00.000           Transportation
# ..            ...     ...                      ...                      ...
# 995  NYCC50532528  NYCC50  2021-03-18T00:00:00.000               Sanitation
# 996  NYCC01512633  NYCC01  2021-03-18T00:00:00.000          General Welfare
# 997  NYCC01512632  NYCC01  2021-03-18T00:00:00.000    Housing and Buildings
# 998  NYCC20505324  NYCC20  2021-03-18T00:00:00.000                Utilities
# 999  NYCC50532523  NYCC50  2021-03-18T00:00:00.000               Sanitation
#
# ...

# %%
df.dtypes
# Out:
# unique_key         object
# account            object
# opendate           object
# complaint_type     object
# zip                object
# borough            object
# city               object
# council_dist       object
# community_board    object
# descriptor         object
# closedate          object
# dtype: object

# %%
df.isnull()
# Out:
#      unique_key  account  opendate  complaint_type    zip  borough   city  \
# 0         False    False     False           False  False    False  False
# 1         False    False     False           False  False    False  False
# 2         False    False     False           False  False    False  False
# 3         False    False     False           False  False    False  False
# 4         False    False     False           False   True     True   True
# ..          ...      ...       ...             ...    ...      ...    ...
# 995       False    False     False           False  False    False  False
# 996       False    False     False           False  False    False  False
# 997       False    False     False           False  False    False  False
# 998       False    False     False           False  False    False  False
# 999       False    False     False           False  False    False  False
#
#      council_dist  community_board  descriptor  closedate
# ...

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.isnull().values.any()
# Out:
# True

# %%
df.isnull().sum()
# Out:
# unique_key           0
# account              0
# opendate             0
# complaint_type      18
# zip                 92
# borough            107
# city                78
# council_dist       102
# community_board     13
# descriptor         125
# closedate          322
# dtype: int64

# %%
df[df['complaint_type'].isnull()]
# Out:
#        unique_key account                 opendate complaint_type    zip  \
# 35   NYCC02525997  NYCC02  2021-04-09T00:00:00.000            NaN  10016
# 36   NYCC34519121  NYCC34  2021-04-09T00:00:00.000            NaN  11237
# 39   NYCC02525996  NYCC02  2021-04-09T00:00:00.000            NaN  10009
# 74   NYCC08507206  NYCC08  2021-04-08T00:00:00.000            NaN  10454
# 89   NYCC29508873  NYCC29  2021-04-08T00:00:00.000            NaN    NaN
# 91   NYCC20505362  NYCC20  2021-04-08T00:00:00.000            NaN  11354
# 210  NYCC29508871  NYCC29  2021-04-06T00:00:00.000            NaN  11375
# 400  NYCC29508870  NYCC29  2021-03-30T00:00:00.000            NaN  11375
# 560  NYCC29508869  NYCC29  2021-03-25T00:00:00.000            NaN  11375
# 611  NYCC02525899  NYCC02  2021-03-24T00:00:00.000            NaN    NaN
# 713  NYCC51505237  NYCC51  2021-03-23T00:00:00.000            NaN  10314
# 717  NYCC50532654  NYCC50  2021-03-23T00:00:00.000            NaN  10301
# ...

# %%
df['date'] = df['opendate'].astype('str')
print(df['date'])
# Out:
# 0      2021-04-11T00:00:00.000
# 1      2021-04-11T00:00:00.000
# 2      2021-04-10T00:00:00.000
# 3      2021-04-10T00:00:00.000
# 4      2021-04-10T00:00:00.000
#                 ...
# 995    2021-03-18T00:00:00.000
# 996    2021-03-18T00:00:00.000
# 997    2021-03-18T00:00:00.000
# 998    2021-03-18T00:00:00.000
# 999    2021-03-18T00:00:00.000
# Name: date, Length: 1000, dtype: object

# %%
## 
print(df['date'].str.split('T').str[0])
# Out:
# 0      2021-04-11
# 1      2021-04-11
# 2      2021-04-10
# 3      2021-04-10
# 4      2021-04-10
#           ...
# 995    2021-03-18
# 996    2021-03-18
# 997    2021-03-18
# 998    2021-03-18
# 999    2021-03-18
# Name: date, Length: 1000, dtype: object

# %%
## [0] take only the first element 
df['date'] = df['opendate'].str.split('T').str[0]
df.date
# Out:
# 0      2021-04-11
# 1      2021-04-11
# 2      2021-04-10
# 3      2021-04-10
# 4      2021-04-10
#           ...
# 995    2021-03-18
# 996    2021-03-18
# 997    2021-03-18
# 998    2021-03-18
# 999    2021-03-18
# Name: date, Length: 1000, dtype: object

# %%
zip_code = pd.read_csv('zipcode.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /var/folders/4b/6hc01_cs6wv6ys6br0kfw4sc0000gn/T/ipykernel_10901/444710506.py in <module>
# ----> 1 zip_code = pd.read_csv('zipcode.csv')
#
# ~/.pyenv/versions/3.8.10/lib/python3.8/site-packages/pandas-1.4.0.dev0+143.g5675cd8ab2-py3.8-macosx-11.3-arm64.egg/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...
