# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
response = requests.get("https://www.bbc.com/")
doc = BeautifulSoup(response.text, 'html.parser')

# %%
# find everything with the class of media-list__item
# each one of these is going to be a row
stories = doc.select('.media-list__item')

# Starting off without ANY rows
rows = []

for story in stories:
    print("----")
    # Starting off knowing NONE of the columns of data for this datapoint?
    row = {}

    row['title'] = story.select_one('h3').text.strip()

    try:
        # Find me a media__link OR a reel_link
        row['href'] = story.select_one('.media__link, .reel__link')['href']
    except:
        print("Couldn't find a link")

    try:
        row['tag'] = story.select_one('.media__tag').text.strip()
    except:
        print("Couldn't find a tag!")

    try:
        row['summary'] = story.select_one('.media__summary').text.strip()
    except:
        print("Couldn't find a summary")

    print(row)
    # When we're done adding info to our row, we're going to add it into our list
    # of rows
    rows.append(row)
# Out:
# ----
# {'title': 'Cubans join rare protests as economy struggles', 'href': '/news/world-latin-america-57799852', 'tag': 'Latin America & Caribbean', 'summary': 'Cubans have been angered by an economic crisis, anti-Covid measures and curbs on civil liberties.'}
# ----
# Couldn't find a summary
# {'title': 'South Africa deploys military to tackle Zuma riots', 'href': 'https://www.bbc.com/news/world-africa-57803513', 'tag': 'Africa'}
# ----
# Couldn't find a summary
# {'title': 'Rashford mural defaced after England Euro defeat', 'href': 'https://www.bbc.com/news/uk-england-manchester-57803161', 'tag': 'Manchester'}
# ----
# Couldn't find a summary
# {'title': 'UK bans fifth neo-Nazi group under terror laws', 'href': 'https://www.bbc.com/news/uk-57806800', 'tag': 'UK'}
# ----
# Couldn't find a summary
# {'title': "The enduring power of 'pay secrecy'", 'href': 'https://www.bbc.com/worklife/article/20210708-pay-secrecy-why-some-workers-cant-discuss-salaries', 'tag': 'Worklife'}
# ----
# {'title': "'Key suspect' held over Haiti president's killing", 'href': '/news/world-latin-america-57800152', 'tag': 'Latin America & Caribbean', 'summary': 'Christian Emmanuel Sanon flew to Haiti on a private jet in June with "political motives", police say.'}
# ----
# {'title': 'Rare protests see thousands on streets of Cuba', 'href': '/news/world-latin-america-57803481', 'tag': 'Latin America & Caribbean', 'summary': 'Protesters say they are angry about the government’s handling of both coronavirus and the economy.'}
# ----
# {'title': 'Inside the Miami building collapse recovery operation', 'href': '/news/world-us-canada-57795441', 'tag': 'US & Canada', 'summary': 'Miami-Dade Fire Rescue show how workers are clearing the "enormous" pile of ruins that remains.'}
# ----
# {'title': 'Reaction after England suffer Euro 2020 final heartbreak', 'href': '/sport/live/football/57800991', 'tag': 'Football', 'summary': 'Reaction as England lose to Italy on penalties in the Euro 2020 final, plus all the latest transfer news.'}
# ----
# {'title': "Italy spoil England's 'coming home' party", 'href': '/sport/football/57800141', 'tag': 'Football', 'summary': "England are left singing the same old song as Italy spoil their 'coming home' party by winning Euro 2020, writes Phil McNulty."}
# ----
# {'title': "'It is down to me' - Southgate rallies around trio", 'href': '/sport/football/57800291', 'tag': 'Football', 'summary': 'All too aware of the pain of a penalty miss, England boss Gareth Southgate rallied around the trio who missed theirs in the Euro 2020 final.'}
# ----
# Couldn't find a tag!
# Couldn't find a summary
# {'title': 'Inside the Frozen Zoo bringing animals back from extinction', 'href': '/reel/video/p09nxnxj/inside-the-frozen-zoo-bringing-animals-back-from-extinction'}
# ----
# Couldn't find a tag!
# Couldn't find a summary
# {'title': 'The Swiss bolthole to escape nuclear war hidden in Ireland', 'href': '/reel/video/p09nnq1v/where-a-swiss-spy-built-the-perfect-hideout-from-nuclear-war'}
# ----
# Couldn't find a tag!
# Couldn't find a summary
# {'title': 'Why our brains never actually take a rest', 'href': '/reel/video/p09mtl6p/why-it-s-good-to-let-your-mind-wander'}
# ----
# {'title': 'What were Neanderthal children like?', 'href': 'https://www.bbc.com/future/article/20210706-the-secret-lives-of-neanderthal-children', 'tag': 'Future', 'summary': 'New archaeological discoveries are giving insights into Neanderthal childhood'}
# ----
# {'title': 'A new era of gay sex in pop', 'href': 'https://www.bbc.com/culture/article/20210708-pops-gay-sexual-revolution', 'tag': 'Culture', 'summary': 'From Lil Nas X to Cardi B: how gay and queer stars are sexing up their acts'}
# ----
# {'title': "How to tell if you have 'boreout'", 'href': 'https://www.bbc.com/worklife/article/20210701-the-damaging-effects-of-boreout-at-work', 'tag': 'Worklife', 'summary': 'Why chronic boredom at work could be as bad as burnout'}
# ----
# {'title': 'The UK town that inspired the Olympics', 'href': 'https://www.bbc.com/travel/article/20210711-the-uk-town-that-inspired-the-olympics', 'tag': 'Travel', 'summary': 'Challenges included a blindfolded wheelbarrow race and an "old women\'s race"'}
# ----
# {'title': 'Euro 2020: Why abuse remains rife on social media', 'href': 'https://www.bbc.com/news/technology-57803940', 'tag': 'Technology', 'summary': "Racist abuse aimed at football players following Sunday's tournament finale has been widely..."}
# ----
# {'title': 'How England fans went from joy to sorrow - pictures', 'href': 'https://www.bbc.com/news/in-pictures-57796519', 'tag': 'In Pictures', 'summary': 'High hopes and nerves give way to fear and sorrow as England lose to Italy on penalties'}
# ----
# {'title': 'Half of staff care less about careers since Covid', 'href': 'https://www.bbc.co.uk/news/business-57798908', 'tag': 'Business', 'summary': 'More of us worry about work-related burnout since the start of the pandemic, an Aviva study shows'}
# ----
# Couldn't find a tag!
# Couldn't find a summary
# {'title': 'The tree boosting Brazilan beef', 'href': '/future/article/20210629-the-australian-tree-cutting-brazilian-beefs-emissions'}
# ----
# Couldn't find a tag!
# Couldn't find a summary
# {'title': 'Why building is so clean in Scandinavia', 'href': '/future/article/20210622-the-scandinavian-way-to-zero-carbon-construction'}
# ----
# Couldn't find a tag!
# Couldn't find a summary
# {'title': 'The idyllic Indian beach that vanished', 'href': '/future/article/20210615-the-force-that-could-redraw-the-peninsula-of-india'}
# ----
# {'title': 'Billionaire Branson rockets to the edge of space', 'href': '/news/science-environment-57797297', 'tag': 'Science & Environment', 'summary': "The UK businessman realises a lifetime's ambition by riding a rocket plane high into the sky."}
# ----
# Couldn't find a summary
# {'title': 'Nicola Roberts criticises online hate bill', 'href': '/news/entertainment-arts-57808653', 'tag': 'Entertainment & Arts'}
# ----
# Couldn't find a summary
# {'title': 'Pollution-eating car shown off at Goodwood Festival', 'href': '/news/technology-57777329', 'tag': 'Technology'}
# ----
# Couldn't find a summary
# {'title': 'Thailand changes vaccination policy as cases spike', 'href': '/news/world-asia-57801251', 'tag': 'Asia'}
# ----
# Couldn't find a summary
# {'title': 'Record numbers of manatees dying in Florida', 'href': '/news/world-us-canada-57802165', 'tag': 'US & Canada'}
# ----
# Couldn't find a summary
# {'title': 'TV audience of 31m watch England lose Euro final', 'href': '/news/entertainment-arts-57802981', 'tag': 'Entertainment & Arts'}
# ----
# Couldn't find a summary
# {'title': 'Woman aged 90 died with double Covid variant', 'href': '/news/health-57761343', 'tag': 'Health'}
# ----
# Couldn't find a summary
# {'title': 'Exhibition reveals people behind rare illnesses', 'href': '/news/uk-wales-57748393', 'tag': 'Wales'}
# ----
# Couldn't find a summary
# {'title': 'Photographer shows the authentic face of black Britain', 'href': '/news/entertainment-arts-57733386', 'tag': 'Entertainment & Arts'}
# ----
# Couldn't find a summary
# {'title': "Africa's top shots: Twirls, fringes and wedding flames", 'href': '/news/world-africa-57763982', 'tag': 'Africa'}
# ----
# Couldn't find a summary
# {'title': "London's air pollution turned into art", 'href': '/news/in-pictures-56986767', 'tag': 'In Pictures'}
# ----
# Couldn't find a summary
# {'title': 'Astronomy photo competition shortlist revealed', 'href': '/news/in-pictures-57653901', 'tag': 'In Pictures'}

# %%
df = pd.DataFrame(rows)
df
# Out:
#                                                 title  \
# 0      Cubans join rare protests as economy struggles
# 1   South Africa deploys military to tackle Zuma r...
# 2    Rashford mural defaced after England Euro defeat
# 3      UK bans fifth neo-Nazi group under terror laws
# 4                 The enduring power of 'pay secrecy'
# 5   'Key suspect' held over Haiti president's killing
# 6      Rare protests see thousands on streets of Cuba
# 7   Inside the Miami building collapse recovery op...
# 8   Reaction after England suffer Euro 2020 final ...
# 9           Italy spoil England's 'coming home' party
# 10  'It is down to me' - Southgate rallies around ...
# 11  Inside the Frozen Zoo bringing animals back fr...
# 12  The Swiss bolthole to escape nuclear war hidde...
# 13          Why our brains never actually take a rest
# 14               What were Neanderthal children like?
# 15                        A new era of gay sex in pop
# 16                  How to tell if you have 'boreout'
# 17             The UK town that inspired the Olympics
# 18  Euro 2020: Why abuse remains rife on social media
# 19  How England fans went from joy to sorrow - pic...
# 20  Half of staff care less about careers since Covid
# 21                    The tree boosting Brazilan beef
# 22            Why building is so clean in Scandinavia
# 23             The idyllic Indian beach that vanished
# 24   Billionaire Branson rockets to the edge of space
# 25         Nicola Roberts criticises online hate bill
# 26  Pollution-eating car shown off at Goodwood Fes...
# 27  Thailand changes vaccination policy as cases s...
# 28        Record numbers of manatees dying in Florida
# 29   TV audience of 31m watch England lose Euro final
# 30       Woman aged 90 died with double Covid variant
# 31    Exhibition reveals people behind rare illnesses
# 32  Photographer shows the authentic face of black...
# 33  Africa's top shots: Twirls, fringes and weddin...
# 34             London's air pollution turned into art
